# %% [markdown]
# # Google Drive のマウント

# %%
from google.colab import drive
from pathlib import Path

drive.mount("/drive")
drive_dir = Path("/drive")
# Out:
# Mounted at /drive

# %% [markdown]
# # 必要なパッケージのインストール

# %% [markdown]
# リポジトリのルートディレクトリを指定してください。

# %%
root_dir = drive_dir / "MyDrive/Colab Notebooks/book-llm-from-scratch"

# %%
# %cd {root_dir.resolve().as_posix()}
# %pip install .
# Out:
# /drive/MyDrive/Colab Notebooks/book-llm-from-scratch
# Processing /drive/MyDrive/Colab Notebooks/book-llm-from-scratch
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: accelerate>=1.10.1 in /usr/local/lib/python3.12/dist-packages (from llm-from-scratch==0.1.0) (1.13.0)
# Requirement already satisfied: beautifulsoup4>=4.12.0 in /usr/local/lib/python3.12/dist-packages (from llm-from-scratch==0.1.0) (4.13.5)
# Collecting datasets>=4.1.0 (from llm-from-scratch==0.1.0)
#   Downloading datasets-4.8.5-py3-none-any.whl.metadata (19 kB)
# Collecting deepspeed>=0.18.3 (from llm-from-scratch==0.1.0)
#   Downloading deepspeed-0.19.0.tar.gz (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 6.3 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Collecting ipywidgets>=8.1.2 (from llm-from-scratch==0.1.0)
#   Downloading ipywidgets-8.1.8-py3-none-any.whl.metadata (2.4 kB)
# Collecting japanize-matplotlib>=1.1.3 (from llm-from-scratch==0.1.0)
#   Downloading japanize-matplotlib-1.1.3.tar.gz (4.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 43.3 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib>=3.8.2 in /usr/local/lib/python3.12/dist-packages (from llm-from-scratch==0.1.0) (3.10.0)
# Collecting neologdn>=0.5.3 (from llm-from-scratch==0.1.0)
#   Downloading neologdn-0.5.6-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (10 kB)
# Collecting notebook>=7.0.6 (from llm-from-scratch==0.1.0)
#   Downloading notebook-7.5.6-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.26.2 in /usr/local/lib/python3.12/dist-packages (from llm-from-scratch==0.1.0) (2.0.2)
# Collecting peft==0.14.0 (from llm-from-scratch==0.1.0)
#   Downloading peft-0.14.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.12/dist-packages (from llm-from-scratch==0.1.0) (2.32.4)
# Collecting rich>=14.3.3 (from llm-from-scratch==0.1.0)
#   Downloading rich-15.0.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: scipy>=1.13.0 in /usr/local/lib/python3.12/dist-packages (from llm-from-scratch==0.1.0) (1.16.3)
# Requirement already satisfied: sentencepiece>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from llm-from-scratch==0.1.0) (0.2.1)
# Requirement already satisfied: tensorboard>=2.12.0 in /usr/local/lib/python3.12/dist-packages (from llm-from-scratch==0.1.0) (2.20.0)
# Requirement already satisfied: tiktoken>=0.11.0 in /usr/local/lib/python3.12/dist-packages (from llm-from-scratch==0.1.0) (0.12.0)
# Requirement already satisfied: tokenizers>=0.15.2 in /usr/local/lib/python3.12/dist-packages (from llm-from-scratch==0.1.0) (0.22.2)
# Requirement already satisfied: torch>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from llm-from-scratch==0.1.0) (2.10.0+cpu)
# Collecting torchtext>=0.16.0 (from llm-from-scratch==0.1.0)
#   Downloading torchtext-0.18.0-cp312-cp312-manylinux1_x86_64.whl.metadata (7.9 kB)
# Requirement already satisfied: tqdm>=4.66.2 in /usr/local/lib/python3.12/dist-packages (from llm-from-scratch==0.1.0) (4.67.3)
# Collecting transformers<4.50.0,>=4.44.0 (from llm-from-scratch==0.1.0)
#   Downloading transformers-4.49.0-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 2.7 MB/s eta 0:00:00
# Collecting trl==0.9.6 (from llm-from-scratch==0.1.0)
#   Downloading trl-0.9.6-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: wandb>=0.23.1 in /usr/local/lib/python3.12/dist-packages (from llm-from-scratch==0.1.0) (0.26.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from peft==0.14.0->llm-from-scratch==0.1.0) (26.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from peft==0.14.0->llm-from-scratch==0.1.0) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from peft==0.14.0->llm-from-scratch==0.1.0) (6.0.3)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from peft==0.14.0->llm-from-scratch==0.1.0) (0.7.0)
# Requirement already satisfied: huggingface-hub>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from peft==0.14.0->llm-from-scratch==0.1.0) (1.11.0)
# Collecting numpy>=1.26.2 (from llm-from-scratch==0.1.0)
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 5.0 MB/s eta 0:00:00
# Collecting tyro>=0.5.11 (from trl==0.9.6->llm-from-scratch==0.1.0)
#   Downloading tyro-1.0.13-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.12.0->llm-from-scratch==0.1.0) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.12.0->llm-from-scratch==0.1.0) (4.15.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets>=4.1.0->llm-from-scratch==0.1.0) (3.29.0)
# Collecting pyarrow>=21.0.0 (from datasets>=4.1.0->llm-from-scratch==0.1.0)
#   Downloading pyarrow-24.0.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=4.1.0->llm-from-scratch==0.1.0) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets>=4.1.0->llm-from-scratch==0.1.0) (2.2.2)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=4.1.0->llm-from-scratch==0.1.0) (0.28.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets>=4.1.0->llm-from-scratch==0.1.0) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.20 in /usr/local/lib/python3.12/dist-packages (from datasets>=4.1.0->llm-from-scratch==0.1.0) (0.70.16)
# Requirement already satisfied: fsspec<=2026.2.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=4.1.0->llm-from-scratch==0.1.0) (2025.3.0)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from deepspeed>=0.18.3->llm-from-scratch==0.1.0) (0.8.2)
# Collecting hjson (from deepspeed>=0.18.3->llm-from-scratch==0.1.0)
#   Downloading hjson-3.1.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.12/dist-packages (from deepspeed>=0.18.3->llm-from-scratch==0.1.0) (1.1.2)
# Collecting ninja (from deepspeed>=0.18.3->llm-from-scratch==0.1.0)
#   Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.12/dist-packages (from deepspeed>=0.18.3->llm-from-scratch==0.1.0) (9.0.0)
# Requirement already satisfied: pydantic>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from deepspeed>=0.18.3->llm-from-scratch==0.1.0) (2.12.3)
# Collecting comm>=0.1.3 (from ipywidgets>=8.1.2->llm-from-scratch==0.1.0)
#   Downloading comm-0.2.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: ipython>=6.1.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets>=8.1.2->llm-from-scratch==0.1.0) (7.34.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.12/dist-packages (from ipywidgets>=8.1.2->llm-from-scratch==0.1.0) (5.7.1)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets>=8.1.2->llm-from-scratch==0.1.0)
#   Downloading widgetsnbextension-4.0.15-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /usr/local/lib/python3.12/dist-packages (from ipywidgets>=8.1.2->llm-from-scratch==0.1.0) (3.0.16)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.2->llm-from-scratch==0.1.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.2->llm-from-scratch==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.2->llm-from-scratch==0.1.0) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.2->llm-from-scratch==0.1.0) (1.5.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.2->llm-from-scratch==0.1.0) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.2->llm-from-scratch==0.1.0) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.2->llm-from-scratch==0.1.0) (2.9.0.post0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from notebook>=7.0.6->llm-from-scratch==0.1.0) (2.14.0)
# Collecting jupyterlab-server<3,>=2.28.0 (from notebook>=7.0.6->llm-from-scratch==0.1.0)
#   Downloading jupyterlab_server-2.28.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting jupyterlab<4.6,>=4.5.7 (from notebook>=7.0.6->llm-from-scratch==0.1.0)
#   Downloading jupyterlab-4.5.7-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /usr/local/lib/python3.12/dist-packages (from notebook>=7.0.6->llm-from-scratch==0.1.0) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from notebook>=7.0.6->llm-from-scratch==0.1.0) (6.5.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->llm-from-scratch==0.1.0) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->llm-from-scratch==0.1.0) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->llm-from-scratch==0.1.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->llm-from-scratch==0.1.0) (2026.4.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=14.3.3->llm-from-scratch==0.1.0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=14.3.3->llm-from-scratch==0.1.0) (2.20.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.12.0->llm-from-scratch==0.1.0) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.12.0->llm-from-scratch==0.1.0) (1.80.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.12.0->llm-from-scratch==0.1.0) (3.10.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.12.0->llm-from-scratch==0.1.0) (5.29.6)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.12.0->llm-from-scratch==0.1.0) (75.2.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.12.0->llm-from-scratch==0.1.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.12.0->llm-from-scratch==0.1.0) (3.1.8)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from tiktoken>=0.11.0->llm-from-scratch==0.1.0) (2025.11.3)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.1->llm-from-scratch==0.1.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.1->llm-from-scratch==0.1.0) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.1->llm-from-scratch==0.1.0) (3.1.6)
# Collecting huggingface-hub>=0.25.0 (from peft==0.14.0->llm-from-scratch==0.1.0)
#   Downloading huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# Collecting tokenizers>=0.15.2 (from llm-from-scratch==0.1.0)
#   Downloading tokenizers-0.21.4-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: click>=8.0.1 in /usr/local/lib/python3.12/dist-packages (from wandb>=0.23.1->llm-from-scratch==0.1.0) (8.3.3)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb>=0.23.1->llm-from-scratch==0.1.0) (3.1.47)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb>=0.23.1->llm-from-scratch==0.1.0) (4.9.6)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb>=0.23.1->llm-from-scratch==0.1.0) (2.58.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=4.1.0->llm-from-scratch==0.1.0) (3.13.5)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb>=0.23.1->llm-from-scratch==0.1.0) (4.0.12)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets>=4.1.0->llm-from-scratch==0.1.0) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets>=4.1.0->llm-from-scratch==0.1.0) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0->datasets>=4.1.0->llm-from-scratch==0.1.0) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.25.0->peft==0.14.0->llm-from-scratch==0.1.0) (1.4.3)
# Collecting jedi>=0.16 (from ipython>=6.1.0->ipywidgets>=8.1.2->llm-from-scratch==0.1.0)
#   Downloading jedi-0.20.0-py2.py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets>=8.1.2->llm-from-scratch==0.1.0) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets>=8.1.2->llm-from-scratch==0.1.0) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets>=8.1.2->llm-from-scratch==0.1.0) (3.0.52)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets>=8.1.2->llm-from-scratch==0.1.0) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets>=8.1.2->llm-from-scratch==0.1.0) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets>=8.1.2->llm-from-scratch==0.1.0) (4.9.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->notebook>=7.0.6->llm-from-scratch==0.1.0) (25.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->notebook>=7.0.6->llm-from-scratch==0.1.0) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->notebook>=7.0.6->llm-from-scratch==0.1.0) (5.9.1)
# Requirement already satisfied: jupyter-events>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->notebook>=7.0.6->llm-from-scratch==0.1.0) (0.12.1)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->notebook>=7.0.6->llm-from-scratch==0.1.0) (0.5.4)
# Requirement already satisfied: nbconvert>=6.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->notebook>=7.0.6->llm-from-scratch==0.1.0) (7.17.1)
# Requirement already satisfied: nbformat>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->notebook>=7.0.6->llm-from-scratch==0.1.0) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->notebook>=7.0.6->llm-from-scratch==0.1.0) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->notebook>=7.0.6->llm-from-scratch==0.1.0) (0.25.0)
# Requirement already satisfied: pyzmq>=24 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->notebook>=7.0.6->llm-from-scratch==0.1.0) (26.2.1)
# Requirement already satisfied: send2trash>=1.8.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->notebook>=7.0.6->llm-from-scratch==0.1.0) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->notebook>=7.0.6->llm-from-scratch==0.1.0) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->notebook>=7.0.6->llm-from-scratch==0.1.0) (1.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.1.1->llm-from-scratch==0.1.0) (3.0.3)
# Collecting async-lru>=1.0.0 (from jupyterlab<4.6,>=4.5.7->notebook>=7.0.6->llm-from-scratch==0.1.0)
#   Downloading async_lru-2.3.0-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: ipykernel!=6.30.0,>=6.5.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab<4.6,>=4.5.7->notebook>=7.0.6->llm-from-scratch==0.1.0) (6.17.1)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab<4.6,>=4.5.7->notebook>=7.0.6->llm-from-scratch==0.1.0)
#   Downloading jupyter_lsp-2.3.1-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: babel>=2.10 in /usr/local/lib/python3.12/dist-packages (from jupyterlab-server<3,>=2.28.0->notebook>=7.0.6->llm-from-scratch==0.1.0) (2.18.0)
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.28.0->notebook>=7.0.6->llm-from-scratch==0.1.0)
#   Downloading json5-0.14.0-py3-none-any.whl.metadata (36 kB)
# Requirement already satisfied: jsonschema>=4.18.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab-server<3,>=2.28.0->notebook>=7.0.6->llm-from-scratch==0.1.0) (4.26.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=14.3.3->llm-from-scratch==0.1.0) (0.1.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0.0->deepspeed>=0.18.3->llm-from-scratch==0.1.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0.0->deepspeed>=0.18.3->llm-from-scratch==0.1.0) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0.0->deepspeed>=0.18.3->llm-from-scratch==0.1.0) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.8.2->llm-from-scratch==0.1.0) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.1.1->llm-from-scratch==0.1.0) (1.3.0)
# Requirement already satisfied: docstring-parser>=0.15 in /usr/local/lib/python3.12/dist-packages (from tyro>=0.5.11->trl==0.9.6->llm-from-scratch==0.1.0) (0.18.0)
# Requirement already satisfied: typeguard>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from tyro>=0.5.11->trl==0.9.6->llm-from-scratch==0.1.0) (4.5.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets>=4.1.0->llm-from-scratch==0.1.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets>=4.1.0->llm-from-scratch==0.1.0) (2026.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=4.1.0->llm-from-scratch==0.1.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=4.1.0->llm-from-scratch==0.1.0) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=4.1.0->llm-from-scratch==0.1.0) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=4.1.0->llm-from-scratch==0.1.0) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=4.1.0->llm-from-scratch==0.1.0) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=4.1.0->llm-from-scratch==0.1.0) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=4.1.0->llm-from-scratch==0.1.0) (1.23.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.12/dist-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=7.0.6->llm-from-scratch==0.1.0) (25.1.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb>=0.23.1->llm-from-scratch==0.1.0) (5.0.3)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.7->notebook>=7.0.6->llm-from-scratch==0.1.0) (1.8.15)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.7->notebook>=7.0.6->llm-from-scratch==0.1.0) (1.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=8.1.2->llm-from-scratch==0.1.0) (0.8.6)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook>=7.0.6->llm-from-scratch==0.1.0) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook>=7.0.6->llm-from-scratch==0.1.0) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook>=7.0.6->llm-from-scratch==0.1.0) (0.30.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook>=7.0.6->llm-from-scratch==0.1.0) (0.4)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=7.0.6->llm-from-scratch==0.1.0) (4.1.0)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=7.0.6->llm-from-scratch==0.1.0) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=7.0.6->llm-from-scratch==0.1.0) (0.1.1)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=7.0.6->llm-from-scratch==0.1.0) (6.3.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=7.0.6->llm-from-scratch==0.1.0) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=7.0.6->llm-from-scratch==0.1.0) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=7.0.6->llm-from-scratch==0.1.0) (3.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=7.0.6->llm-from-scratch==0.1.0) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=7.0.6->llm-from-scratch==0.1.0) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=7.0.6->llm-from-scratch==0.1.0) (2.21.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=8.1.2->llm-from-scratch==0.1.0) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=6.1.0->ipywidgets>=8.1.2->llm-from-scratch==0.1.0) (0.6.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=7.0.6->llm-from-scratch==0.1.0) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=7.0.6->llm-from-scratch==0.1.0) (1.4.0)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=7.0.6->llm-from-scratch==0.1.0) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=7.0.6->llm-from-scratch==0.1.0) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=7.0.6->llm-from-scratch==0.1.0) (3.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=7.0.6->llm-from-scratch==0.1.0) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=7.0.6->llm-from-scratch==0.1.0) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=7.0.6->llm-from-scratch==0.1.0) (25.10.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=7.0.6->llm-from-scratch==0.1.0) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=7.0.6->llm-from-scratch==0.1.0) (3.0)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=7.0.6->llm-from-scratch==0.1.0) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=7.0.6->llm-from-scratch==0.1.0) (1.4.0)
# Downloading peft-0.14.0-py3-none-any.whl (374 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.8/374.8 kB 23.4 MB/s eta 0:00:00
# Downloading trl-0.9.6-py3-none-any.whl (245 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.8/245.8 kB 16.9 MB/s eta 0:00:00
# Downloading datasets-4.8.5-py3-none-any.whl (528 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 529.0/529.0 kB 34.4 MB/s eta 0:00:00
# Downloading ipywidgets-8.1.8-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 11.3 MB/s eta 0:00:00
# Downloading neologdn-0.5.6-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (266 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.6/266.6 kB 18.5 MB/s eta 0:00:00
# Downloading notebook-7.5.6-py3-none-any.whl (14.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 47.5 MB/s eta 0:00:0000:0100:01
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 48.4 MB/s eta 0:00:0000:0100:01
# Downloading rich-15.0.0-py3-none-any.whl (310 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.7/310.7 kB 24.1 MB/s eta 0:00:00
# Downloading torchtext-0.18.0-cp312-cp312-manylinux1_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 77.0 MB/s eta 0:00:00
# Downloading transformers-4.49.0-py3-none-any.whl (10.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 65.2 MB/s eta 0:00:0000:010:01m
# Downloading tokenizers-0.21.4-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 96.7 MB/s eta 0:00:00
# Downloading comm-0.2.3-py3-none-any.whl (7.3 kB)
# Downloading huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 35.9 MB/s eta 0:00:00
# Downloading jupyterlab-4.5.7-py3-none-any.whl (12.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.5/12.5 MB 49.8 MB/s eta 0:00:0000:0100:01
# Downloading jupyterlab_server-2.28.0-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.8/59.8 kB 4.3 MB/s eta 0:00:00
# Downloading pyarrow-24.0.0-cp312-cp312-manylinux_2_28_x86_64.whl (48.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 MB 10.9 MB/s eta 0:00:0000:0100:01
# Downloading tyro-1.0.13-py3-none-any.whl (185 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 185.2/185.2 kB 15.5 MB/s eta 0:00:00
# Downloading widgetsnbextension-4.0.15-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 82.2 MB/s eta 0:00:00
# Downloading hjson-3.1.0-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 kB 4.4 MB/s eta 0:00:00
# Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (180 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 15.4 MB/s eta 0:00:00
# Downloading async_lru-2.3.0-py3-none-any.whl (8.4 kB)
# Downloading jedi-0.20.0-py2.py3-none-any.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 63.3 MB/s eta 0:00:0000:01:00:01
# Downloading json5-0.14.0-py3-none-any.whl (36 kB)
# Downloading jupyter_lsp-2.3.1-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 kB 4.1 MB/s eta 0:00:00
# Building wheels for collected packages: llm-from-scratch, deepspeed, japanize-matplotlib
#   Building wheel for llm-from-scratch (pyproject.toml) ... done
#   Created wheel for llm-from-scratch: filename=llm_from_scratch-0.1.0-py3-none-any.whl size=14528 sha256=d7b8a5a07780e7ef3f86e6f4a349b522163afad0b58efeda52a92ecb1051c641
#   Stored in directory: /root/.cache/pip/wheels/de/82/b7/ac39b66d1e51a67a9da5d1d910137fb14476c2100bf681f0a1
#   Building wheel for deepspeed (setup.py) ... done
#   Created wheel for deepspeed: filename=deepspeed-0.19.0-py3-none-any.whl size=1842906 sha256=1bfb6b3f91a0f5c090fa3724cf46a91be5ca755b5cc947fbd1fb284fb0072b93
#   Stored in directory: /root/.cache/pip/wheels/e9/b8/60/ae293108c520a820f07e87df91bfc8c2cc24843116fe8cb329
#   Building wheel for japanize-matplotlib (setup.py) ... done
#   Created wheel for japanize-matplotlib: filename=japanize_matplotlib-1.1.3-py3-none-any.whl size=4120257 sha256=2a5a56da7badba0cf332cfd948d7e10a3ed668c6d4491609fc8a3d0b79783677
#   Stored in directory: /root/.cache/pip/wheels/c1/f7/9b/418f19a7b9340fc16e071e89efc379aca68d40238b258df53d
# Successfully built llm-from-scratch deepspeed japanize-matplotlib
# Installing collected packages: neologdn, hjson, widgetsnbextension, pyarrow, numpy, ninja, json5, jedi, comm, async-lru, tyro, rich, huggingface-hub, torchtext, tokenizers, ipywidgets, deepspeed, transformers, japanize-matplotlib, datasets, trl, peft, jupyterlab-server, jupyter-lsp, jupyterlab, notebook, llm-from-scratch
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.6.10
#     Uninstalling widgetsnbextension-3.6.10:
#       Successfully uninstalled widgetsnbextension-3.6.10
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 18.1.0
#     Uninstalling pyarrow-18.1.0:
#       Successfully uninstalled pyarrow-18.1.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: rich
#     Found existing installation: rich 13.9.4
#     Uninstalling rich-13.9.4:
#       Successfully uninstalled rich-13.9.4
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface_hub 1.11.0
#     Uninstalling huggingface_hub-1.11.0:
#       Successfully uninstalled huggingface_hub-1.11.0
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.22.2
#     Uninstalling tokenizers-0.22.2:
#       Successfully uninstalled tokenizers-0.22.2
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.7.1
#     Uninstalling ipywidgets-7.7.1:
#       Successfully uninstalled ipywidgets-7.7.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.0.0
#     Uninstalling transformers-5.0.0:
#       Successfully uninstalled transformers-5.0.0
#   Attempting uninstall: datasets
#     Found existing installation: datasets 4.0.0
#     Uninstalling datasets-4.0.0:
#       Successfully uninstalled datasets-4.0.0
#   Attempting uninstall: peft
#     Found existing installation: peft 0.19.1
#     Uninstalling peft-0.19.1:
#       Successfully uninstalled peft-0.19.1
#   Attempting uninstall: notebook
#     Found existing installation: notebook 6.5.7
#     Uninstalling notebook-6.5.7:
#       Successfully uninstalled notebook-6.5.7
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# pytensor 2.38.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# jupyter-kernel-gateway 2.5.2 requires notebook<7.0,>=5.7.6, but you have notebook 7.5.6 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# pyiceberg 0.11.1 requires rich<15.0.0,>=10.11.0, but you have rich 15.0.0 which is incompatible.
# shap 0.51.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# bigframes 2.39.0 requires rich<14,>=12.4.4, but you have rich 15.0.0 which is incompatible.
# tifffile 2026.4.11 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# tobler 0.14.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# Successfully installed async-lru-2.3.0 comm-0.2.3 datasets-4.8.5 deepspeed-0.19.0 hjson-3.1.0 huggingface-hub-0.36.2 ipywidgets-8.1.8 japanize-matplotlib-1.1.3 jedi-0.20.0 json5-0.14.0 jupyter-lsp-2.3.1 jupyterlab-4.5.7 jupyterlab-server-2.28.0 llm-from-scratch-0.1.0 neologdn-0.5.6 ninja-1.13.0 notebook-7.5.6 numpy-1.26.4 peft-0.14.0 pyarrow-24.0.0 rich-15.0.0 tokenizers-0.21.4 torchtext-0.18.0 transformers-4.49.0 trl-0.9.6 tyro-1.0.13 widgetsnbextension-4.0.15

# %% [markdown]
# # 2.2.2

# %%
import numpy as np


def softmax(x: np.ndarray) -> np.ndarray:
    e_x = np.exp(x - np.max(x))
    return e_x / e_x.sum(axis=-1, keepdims=True)


def attention(Q: np.ndarray, K: np.ndarray, V: np.ndarray) -> tuple[np.ndarray, np.ndarray]:
    attention_weights = softmax(np.matmul(Q, K.T))
    return np.matmul(attention_weights, V), attention_weights

# %%
import matplotlib.pyplot as plt
import japanize_matplotlib


def plot_vectors(vectors, texts, ax, arrow_args={}, text_args={}):
    for i, (x, y) in enumerate(vectors):
        ax.annotate("", xy=[x, y], xytext=[0, 0], arrowprops=arrow_args)
        ax.text(x * 1.1, y * 1.1, texts[i], **text_args)


def plot_attention_hist(attention_weights, ax):
    ax.bar(range(len(attention_weights)), attention_weights)
    ax.set_xticks(range(len(attention_weights)))
    ax.set_xticklabels([f"$v_{i+1}$" for i in range(len(attention_weights))])
    ax.set_ylabel("注意度")

# %%
import math

n = 10
vectors = []
# 360°をn等分した角度
theta = 2 * math.pi / n
for i in range(n):
    x = math.cos(theta * i)
    y = math.sin(theta * i)
    vectors.append([x, y])

vectors = np.array(vectors)
query = np.array([1 / math.sqrt(2), 1 / math.sqrt(2)])
output, attention_weights = attention(query, vectors, vectors)
print("出力ベクトル:", output)
print("注意度の形:", attention_weights.shape)
print("注意度の和:", attention_weights.sum())
# Out:
# 出力ベクトル: [0.31564538 0.31564537]
# 注意度の形: (10,)
# 注意度の和: 1.0000000000000002

# %%
# vectors と query をプロット
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(5, 5))
texts = [f"$v_{{{i+1}}}$" for i in range(n)]
arrow_args1 = dict(
    width=1, headwidth=8, headlength=10, facecolor="gray", edgecolor="gray"
)
text_args1 = dict(ha="center", va="center")
plot_vectors(
    vectors,
    texts,
    ax,
    arrow_args=arrow_args1,
    text_args=text_args1,
)
arrow_args2 = dict(
    width=1, headwidth=8, headlength=10, facecolor="red", edgecolor="red"
)
text_args2 = dict(ha="center", va="center", color="red")
plot_vectors([query], ["query"], ax, arrow_args=arrow_args2, text_args=text_args2)
ax.set_xlim(-1.5, 1.5)
ax.set_ylim(-1.5, 1.5)

fig.savefig("vectors_and_query.png", dpi=144)
plt.show()

# %%
# attention weights をプロット
def plot_attention_weights(vectors, query, output, attention_weights, ax):
    texts = [f"{a:.3f}" for a in attention_weights]

    arrow_args1 = dict(
        width=1, headwidth=8, headlength=10, facecolor="gray", edgecolor="gray"
    )
    text_args1 = dict(ha="center", va="center")
    plot_vectors(
        vectors,
        texts,
        ax,
        arrow_args=arrow_args1,
        text_args=text_args1,
    )
    arrow_args2 = dict(
        width=1, headwidth=8, headlength=10, facecolor="red", edgecolor="red"
    )
    text_args2 = dict(ha="center", va="center", color="red")
    plot_vectors([query], ["query"], ax, arrow_args=arrow_args2, text_args=text_args2)

    arrow_args3 = dict(
        width=1, headwidth=8, headlength=10, facecolor="blue", edgecolor="blue"
    )
    text_args3 = dict(ha="center", va="center", color="blue")
    plot_vectors([output], ["output"], ax, arrow_args=arrow_args3, text_args=text_args3)


fig, ax = plt.subplots(figsize=(5, 5))
plot_attention_weights(vectors, query, output, attention_weights, ax)
ax.set_xlim(-1.5, 1.5)
ax.set_ylim(-1.5, 1.5)

fig.savefig("attention_weights.png", dpi=144)
plt.show()

# %%
# 1つだけ長いベクトルがある場合の実験

vectors2 = vectors.copy()
vectors2[3] = vectors2[3] * 5

_, attention_weights2 = attention(query, vectors2, vectors2)

# %%
fig, ax = plt.subplots(figsize=(5, 5))
plot_attention_hist(attention_weights, ax)
ax.set_ylim(0, 0.5)
fig.savefig("attention_weights_hist1.png", dpi=144)
plt.show()
fig, ax = plt.subplots(figsize=(5, 5))
ax.set_ylim(0, 0.5)
plot_attention_hist(attention_weights2, ax)
fig.savefig("attention_weights_hist2.png", dpi=144)
plt.show()

# %%
queries = np.array([[1 / math.sqrt(2), 1 / math.sqrt(2)], [1, 0], [0, 1]])

output, attention_weights = attention(queries, vectors, vectors)
print("出力の形:", output.shape)
print("注意度行列の形:", attention_weights.shape)
print("注意度の行ごとの和:", attention_weights.sum(axis=1))
# Out:
# 出力の形: (3, 2)
# 注意度行列の形: (3, 10)
# 注意度の行ごとの和: [1. 1. 1.]

# %% [markdown]
# # 2.2.3

# %%
import numpy as np


def softmax(x: np.ndarray) -> np.ndarray:
    e_x = np.exp(x - np.max(x))
    return e_x / e_x.sum(axis=-1, keepdims=True)


def attention(Q: np.ndarray, K: np.ndarray, V: np.ndarray) -> tuple[np.ndarray, np.ndarray]:
    attention_weights = softmax(np.matmul(Q, K.T))
    return np.matmul(attention_weights, V), attention_weights

# %%
x1 = np.random.randn(100) * 10
x2 = np.random.randn(100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_5166/1223499829.py in <cell line: 0>()
# ----> 1 x1 = np.random.randn(100) * 10
#       2 x2 = np.random.randn(100)
#
# /usr/local/lib/python3.12/dist-packages/numpy/__init__.py in __getattr__(attr)
#     335
#     336     def __dir__():
# --> 337         public_symbols = globals().keys() | {'testing'}
#     338         public_symbols -= {
#     339             "core", "matrixlib",
#
# /usr/local/lib/python3.12/dist-packages/numpy/random/__init__.py in <module>
#     178
#     179 # add these for module-freeze analysis (like PyInstaller)
# --> 180 from . import _pickle
#     181 from . import _common
#     182 from . import _bounded_integers
#
# /usr/local/lib/python3.12/dist-packages/numpy/random/_pickle.py in <module>
# ----> 1 from .mtrand import RandomState
#       2 from ._philox import Philox
#       3 from ._pcg64 import PCG64, PCG64DXSM
#       4 from ._sfc64 import SFC64
#       5
#
# numpy/random/mtrand.pyx in init numpy.random.mtrand()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject

# %%
import matplotlib.pyplot as plt
import japanize_matplotlib

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))
ax1.scatter(x1, softmax(x1), s=3)
ax2.scatter(x2, softmax(x2), s=3)
# ax1.set_ylim(-0.001, 0.1)
ax2.set_ylim(-0.001, 0.1)
ax1.set_xlabel("入力")
ax2.set_xlabel("入力")
ax1.set_ylabel("出力")

fig.savefig("softmax_different_ranges.png", dpi=144)

# %%
dim1 = 1
dim2 = 100
n_keys = 20

q1 = np.random.randn(dim1)
q2 = np.random.randn(dim2)
k1 = np.random.randn(n_keys, dim1)
k2 = np.random.randn(n_keys, dim2)

# %%
dot1 = np.matmul(k1, q1)
s1_1 = softmax(dot1)
s1_2 = softmax(dot1 / np.sqrt(dim1))

dot2 = np.matmul(k2, q2)
s2_1 = softmax(dot2)
s2_2 = softmax(dot2 / np.sqrt(dim2))

# %%
fig, ax = plt.subplots(2, 2, figsize=(12, 12))

max_1_2 = max(np.max(s1_2), np.max(s2_2))
ax[0, 0].scatter(dot1, s1_1, s=5)
ax[0, 0].set_title(f"{dim1} 次元, スケーリングなし")
ax[0, 0].set_ylim(-0.01, max_1_2 + 0.1)
ax[0, 1].scatter(dot1, s1_2, s=5)
ax[0, 1].set_title(f"{dim1} 次元, スケーリングあり")
ax[0, 1].set_ylim(-0.01, max_1_2 + 0.1)
ax[1, 0].scatter(dot2, s2_1, s=5)
ax[1, 0].set_title(f"{dim2} 次元, スケーリングなし")
ax[1, 1].scatter(dot2, s2_2, s=5)
ax[1, 1].set_title(f"{dim2} 次元, スケーリングあり")
ax[1, 1].set_ylim(-0.01, max_1_2 + 0.1)

fig.savefig("softmax_scaling.png", dpi=144)

# %%
def scaled_attention(Q, K, V):
    dim = Q.shape[-1]
    attention_weights = softmax(np.matmul(Q, K.T) / np.sqrt(dim))
    return np.matmul(attention_weights, V), attention_weights
